# %% [markdown]
# # Module One Partner Project
# ### Created by: Andy Luc and Connor Anderson
# ### Student Pace: Full-Time Data Science
# ### Scheduled project review date/time: 04/19/2019
# ### Instructors: Miles Erickson & Greg Damico
# ### Blog Post URL: https://dev.to/rokaandy/logarithmic-transformation-in-linear-regression-models-why-when-3a7c

# %% [markdown]
# # Business Case:
#
# We work for a real estate company like Windermere or Madrona. Our agents have a group of customers who are looking to sell their homes in the near future, but they would like to know what renovations to add to their homes in order to increase the value and get the most return on investment.
# Our 3 main questions:
# 1. What factors influence price the most?
# 2. What factors are feasible for renovation
# 3. How accurately can we predict the value these features will have on price?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing Data
#
# #### Source: King County Housing Data
# #### Timespan of the data (URL): This dataset is from 9/9/2014 - 1/10/2015

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0            0.0     1955           0.0    98178  47.5112 -122.257
# 1          400.0     1951        1991.0    98125  47.7210 -122.319
# 2            0.0     1933           NaN    98028  47.7379 -122.233
# 3          910.0     1965           0.0    98136  47.5208 -122.393
# 4            0.0     1987           0.0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %%
df.head().T
# Out:
#                         0           1           2           3           4
# id             7129300520  6414100192  5631500400  2487200875  1954400510
# date           10/13/2014   12/9/2014   2/25/2015   12/9/2014   2/18/2015
# price              221900      538000      180000      604000      510000
# bedrooms                3           3           2           4           3
# bathrooms               1        2.25           1           3           2
# sqft_living          1180        2570         770        1960        1680
# sqft_lot             5650        7242       10000        5000        8080
# floors                  1           2           1           1           1
# waterfront            NaN           0           0           0           0
# view                    0           0           0           0           0
# condition               3           3           3           5           3
# grade                   7           7           6           7           8
# sqft_above           1180        2170         770        1050        1680
# sqft_basement         0.0       400.0         0.0       910.0         0.0
# yr_built             1955        1951        1933        1965        1987
# yr_renovated            0        1991         NaN           0           0
# zipcode             98178       98125       98028       98136       98074
# lat               47.5112      47.721     47.7379     47.5208     47.6168
# long             -122.257    -122.319    -122.233    -122.393    -122.045
# sqft_living15        1340        1690        2720        1360        1800
# sqft_lot15           5650        7639        8062        5000        7503

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
# # Data Preparation

# %% [markdown]
# After looking through the original data and assesing what data was going to be valuable to answer our question, we decided to drop the columns titled (id, yr_renovated, lat, and long). This gave us a smaller data set in which we then proceeded to clean by dropping NaN and ? values from the waterfront and view columns.

# %%
'''King County DataFrame that Includes logs of various variables '''
kc_data_full = pd.read_csv('kc_house_data.csv')
kc_data_full['sqft_basement'] = kc_data_full['sqft_basement'].replace("?",0)
kc_data_full['sqft_basement'] = kc_data_full['sqft_basement'].astype(float)
kc_data_full['zipcode'] = kc_data_full['zipcode'].astype(str)

kc_data_full = kc_data_full[~np.isnan(kc_data_full['waterfront'])]
kc_data_full = kc_data_full[~np.isnan(kc_data_full['view'])]

kc_data_full = kc_data_full.drop(['id','yr_renovated','lat','long'], axis=1)

# %% [markdown]
# #### Note: After dropping NaN records from waterfront and view, `kc_data_full` used to have 21,597 records, but now it has 19,164.

# %% [markdown]
# # Exploratory Data Analysis:
# - Visualization
# - OLS Model
# - Multi-collinearity

# %% [markdown]
# ## Visualization
#
# Pairplot of Sqft Living, Bedrooms, Bathrooms in relation to Price.

# %%
_=kc_data_full.hist(figsize=(15,15))

# %% [markdown]
# ### Observations from the histograms above:
#    Our target variable, price, is not a currently in a normal distribution. Most of the data appears to be skewed to the left side of the chart. We will have to normalize that data in order for our linear regression model to work properly. There are several other variables(sqft_living, bedrooms, yr_built) that we may normalize in order to see what change it has on our model.
#
#    We also only used houses that were built after 1975, seeing as those houses would likley need rennovation, but are still likley to have a higher grade than house built before this time, and grade has a strong impact on the price.

# %%
kc_train = kc_data_full[:9000]
kc_train = kc_train.loc[kc_train['yr_built'] > 1975]

log_sqft_living = np.log(kc_train['sqft_living'])
log_bedrooms = np.log(kc_train['bedrooms'])
log_yr_built = np.log(kc_train['yr_built'])

kc_train['log_sqft'] = log_sqft_living
kc_train['log_bedrooms'] = log_bedrooms
kc_train['log_yr_built'] = log_yr_built

kc_train['price'] = np.log(kc_train['price'])

# %%
kc_train.head()
# Out:
#          date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 4   2/18/2015  13.142166         3       2.00         1680      8080     1.0
# 5   5/12/2014  14.022525         4       4.50         5420    101930     1.0
# 6   6/27/2014  12.458775         3       2.25         1715      6819     2.0
# 9   3/12/2015  12.685408         3       2.50         1890      6560     2.0
# 13  10/7/2014  12.899220         3       1.75         1370      9680     1.0
#
#     waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 4          0.0   0.0          3      8        1680            0.0      1987
# 5          0.0   0.0          3     11        3890         1530.0      2001
# 6          0.0   0.0          3      7        1715            0.0      1995
# 9          0.0   0.0          3      7        1890            0.0      2003
# 13         0.0   0.0          4      7        1370            0.0      1977
#
#    zipcode  sqft_living15  sqft_lot15  log_sqft  log_bedrooms  log_yr_built
# 4    98074           1800        7503  7.426549      1.098612      7.594381
# 5    98053           4760      101930  8.597851      1.386294      7.601402
# 6    98003           2238        6819  7.447168      1.098612      7.598399
# 9    98038           2390        7570  7.544332      1.098612      7.602401
# 13   98074           1370       10208  7.222566      1.098612      7.589336

# %%
_=sns.pairplot(kc_train,x_vars=['log_sqft','grade'], y_vars='price', kind='reg')
plt.savefig('pairplot_graph.png')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# We used this pairplot in order to vizualize and understand if there were linear relationships between these variables and price.

# %%
_=kc_train.hist(figsize=(15,15))

# %% [markdown]
# #### This visual displays that after we normalized the features `'log_sqft', 'price', 'log_bedrooms, 'log_yr_built'` that they are all shaped in a much more normal distribution

# %% [markdown]
# ## Multi-Collinearity of Features

# %% [markdown]
# ### Before we create our models, in order to avoid overfitting to our train data we need to understand which variables may have strong correlations with each other so we can try and avoid those later in our model.

# %%
sns.set(style="white")

# Create a covariance matrix
corr = kc_train.corr()

# Generate a mask the size of our covariance matrix
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11,9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220,10,as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,mask=mask,cmap=cmap,vmax=1,center=0,square=True, 
            linewidth=.5, cbar_kws={'shrink': .5})

ax.set_title('Multi-Collinearity of Features')
plt.savefig('correlation.png')

# %% [markdown]
# #### The chart below shows the numerical way of describing the collinearity between features. As we get closer to 1, they are more highly correlated and should not be used in the same model.

# %%
(kc_train.iloc[:, 1:]).corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.333824   0.573733     0.750144  0.159711  0.263915
# bedrooms       0.333824  1.000000   0.525243     0.555573 -0.001710  0.109082
# bathrooms      0.573733  0.525243   1.000000     0.707180  0.060535  0.342931
# sqft_living    0.750144  0.555573   0.707180     1.000000  0.194875  0.205426
# sqft_lot       0.159711 -0.001710   0.060535     0.194875  1.000000 -0.047022
# floors         0.263915  0.109082   0.342931     0.205426 -0.047022  1.000000
# waterfront     0.228608 -0.007361   0.116618     0.155907 -0.003252  0.028097
# view           0.342739  0.090041   0.247188     0.316483  0.041593  0.045996
# condition     -0.033542  0.023444  -0.101347    -0.029695  0.022280 -0.253236
# grade          0.776819  0.310787   0.559682     0.753803  0.137697  0.302438
# sqft_above     0.692023  0.483128   0.623351     0.889693  0.190751  0.405470
# sqft_basement  0.217946  0.219746   0.264076     0.356907  0.033682 -0.374519
# yr_built       0.188935  0.039705   0.319541     0.164610 -0.032241  0.544567
# sqft_living15  0.649516  0.415628   0.493643     0.773300  0.139313  0.165609
# sqft_lot15     0.151156 -0.008923   0.033165     0.197398  0.714033 -0.054951
# log_sqft       0.730969  0.597750   0.685688     0.962018  0.184144  0.221746
# log_bedrooms   0.324619  0.976754   0.507111     0.539466 -0.003813  0.105932
# log_yr_built   0.188902  0.039659   0.319677     0.164710 -0.032068  0.544850
#
#                waterfront      view  condition     grade  sqft_above  \
# price            0.228608  0.342739  -0.033542  0.776819    0.692023
# bedrooms        -0.007361  0.090041   0.023444  0.310787    0.483128
# bathrooms        0.116618  0.247188  -0.101347  0.559682    0.623351
# sqft_living      0.155907  0.316483  -0.029695  0.753803    0.889693
# sqft_lot        -0.003252  0.041593   0.022280  0.137697    0.190751
# floors           0.028097  0.045996  -0.253236  0.302438    0.405470
# waterfront       1.000000  0.408114  -0.010434  0.143704    0.108372
# view             0.408114  1.000000   0.028578  0.283684    0.192631
# condition       -0.010434  0.028578   1.000000 -0.090826   -0.116267
# grade            0.143704  0.283684  -0.090826  1.000000    0.742900
# sqft_above       0.108372  0.192631  -0.116267  0.742900    1.000000
# sqft_basement    0.119347  0.286798   0.170047  0.121558   -0.103540
# yr_built        -0.006491 -0.020116  -0.418058  0.210972    0.293094
# sqft_living15    0.092023  0.228497  -0.028857  0.726653    0.765312
# sqft_lot15       0.009222  0.033674   0.036486  0.129403    0.185288
# log_sqft         0.116600  0.271105  -0.033000  0.732353    0.872224
# log_bedrooms    -0.013462  0.078472   0.026226  0.311303    0.476540
# log_yr_built    -0.006466 -0.020094  -0.418352  0.211174    0.293429
#
#                sqft_basement  yr_built  sqft_living15  sqft_lot15  log_sqft  \
# price               0.217946  0.188935       0.649516    0.151156  0.730969
# bedrooms            0.219746  0.039705       0.415628   -0.008923  0.597750
# bathrooms           0.264076  0.319541       0.493643    0.033165  0.685688
# sqft_living         0.356907  0.164610       0.773300    0.197398  0.962018
# sqft_lot            0.033682 -0.032241       0.139313    0.714033  0.184144
# floors             -0.374519  0.544567       0.165609   -0.054951  0.221746
# waterfront          0.119347 -0.006491       0.092023    0.009222  0.116600
# view                0.286798 -0.020116       0.228497    0.033674  0.271105
# condition           0.170047 -0.418058      -0.028857    0.036486 -0.033000
# grade               0.121558  0.210972       0.726653    0.129403  0.732353
# sqft_above         -0.103540  0.293094       0.765312    0.185288  0.872224
# sqft_basement       1.000000 -0.236070       0.116163    0.047452  0.309706
# yr_built           -0.236070  1.000000       0.117296   -0.064380  0.150051
# sqft_living15       0.116163  0.117296       1.000000    0.185700  0.782653
# sqft_lot15          0.047452 -0.064380       0.185700    1.000000  0.186331
# log_sqft            0.309706  0.150051       0.782653    0.186331  1.000000
# log_bedrooms        0.198291  0.026099       0.422371   -0.009051  0.598404
# log_yr_built       -0.236534  0.999997       0.117546   -0.064203  0.150184
#
#                log_bedrooms  log_yr_built
# price              0.324619      0.188902
# bedrooms           0.976754      0.039659
# bathrooms          0.507111      0.319677
# sqft_living        0.539466      0.164710
# sqft_lot          -0.003813     -0.032068
# floors             0.105932      0.544850
# waterfront        -0.013462     -0.006466
# view               0.078472     -0.020094
# condition          0.026226     -0.418352
# grade              0.311303      0.211174
# sqft_above         0.476540      0.293429
# sqft_basement      0.198291     -0.236534
# yr_built           0.026099      0.999997
# sqft_living15      0.422371      0.117546
# sqft_lot15        -0.009051     -0.064203
# log_sqft           0.598404      0.150184
# log_bedrooms       1.000000      0.026113
# log_yr_built       0.026113      1.000000

# %% [markdown]
# #### The chart here is stating that any feature that has a collinearity of .75 or higher should be dropped from the dataframe to possibly achieve a better predictability model. Hence, any coefficient that has the highest number of "True" should be analyzed.

# %%
abs(kc_train.corr()) > .75
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# price           True     False      False         True     False   False
# bedrooms       False      True      False        False     False   False
# bathrooms      False     False       True        False     False   False
# sqft_living     True     False      False         True     False   False
# sqft_lot       False     False      False        False      True   False
# floors         False     False      False        False     False    True
# waterfront     False     False      False        False     False   False
# view           False     False      False        False     False   False
# condition      False     False      False        False     False   False
# grade           True     False      False         True     False   False
# sqft_above     False     False      False         True     False   False
# sqft_basement  False     False      False        False     False   False
# yr_built       False     False      False        False     False   False
# sqft_living15  False     False      False         True     False   False
# sqft_lot15     False     False      False        False     False   False
# log_sqft       False     False      False         True     False   False
# log_bedrooms   False      True      False        False     False   False
# log_yr_built   False     False      False        False     False   False
#
#                waterfront   view  condition  grade  sqft_above  sqft_basement  \
# price               False  False      False   True       False          False
# bedrooms            False  False      False  False       False          False
# bathrooms           False  False      False  False       False          False
# sqft_living         False  False      False   True        True          False
# sqft_lot            False  False      False  False       False          False
# floors              False  False      False  False       False          False
# waterfront           True  False      False  False       False          False
# view                False   True      False  False       False          False
# condition           False  False       True  False       False          False
# grade               False  False      False   True       False          False
# sqft_above          False  False      False  False        True          False
# sqft_basement       False  False      False  False       False           True
# yr_built            False  False      False  False       False          False
# sqft_living15       False  False      False  False        True          False
# sqft_lot15          False  False      False  False       False          False
# log_sqft            False  False      False  False        True          False
# log_bedrooms        False  False      False  False       False          False
# log_yr_built        False  False      False  False       False          False
#
#                yr_built  sqft_living15  sqft_lot15  log_sqft  log_bedrooms  \
# price             False          False       False     False         False
# bedrooms          False          False       False     False          True
# bathrooms         False          False       False     False         False
# sqft_living       False           True       False      True         False
# sqft_lot          False          False       False     False         False
# floors            False          False       False     False         False
# waterfront        False          False       False     False         False
# view              False          False       False     False         False
# condition         False          False       False     False         False
# grade             False          False       False     False         False
# sqft_above        False           True       False      True         False
# sqft_basement     False          False       False     False         False
# yr_built           True          False       False     False         False
# sqft_living15     False           True       False      True         False
# sqft_lot15        False          False        True     False         False
# log_sqft          False           True       False      True         False
# log_bedrooms      False          False       False     False          True
# log_yr_built       True          False       False     False         False
#
#                log_yr_built
# price                 False
# bedrooms              False
# bathrooms             False
# sqft_living           False
# sqft_lot              False
# floors                False
# waterfront            False
# view                  False
# condition             False
# grade                 False
# sqft_above            False
# sqft_basement         False
# yr_built               True
# sqft_living15         False
# sqft_lot15            False
# log_sqft              False
# log_bedrooms          False
# log_yr_built           True

# %% [markdown]
# # Modeling

# %% [markdown]
# ### OLS Modeling
# ##### Using Statsmodels
#
# Our first model is a super simple OLS regression based on the relationship between price and square footage. We know from experince that houses with larger sqaure footage generally are more expensive, so we think this is a good place to start

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
f = 'price~log_sqft_living'

model = ols(formula=f, data=kc_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.534
# Method:                 Least Squares   F-statistic:                     4609.
# Date:                Fri, 19 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:45:19   Log-Likelihood:                -1420.4
# No. Observations:                4019   AIC:                             2845.
# Df Residuals:                    4017   BIC:                             2857.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           5.4504      0.113     48.297      0.000       5.229       5.672
# log_sqft_living     0.9930      0.015     67.890      0.000       0.964       1.022
# ==============================================================================
# Omnibus:                       39.425   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.341
# Skew:                           0.243   Prob(JB):                     1.74e-09
# Kurtosis:                       3.061   Cond. No.                         163.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model.params
# Out:
# Intercept          5.450442
# log_sqft_living    0.993040
# dtype: float64

# %%
fig = plt.figure(figsize =(15,8))
fig = sm.graphics.plot_regress_exog(model, 'log_sqft_living', fig=fig)

# %% [markdown]
# ## Linear Regression Modeling

# %% [markdown]
# #### Modeling using Sklearn

# %%
import sklearn
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Input: 
# df = Dataframe
# Feature_cols - A list of strings referencing each feature

# Output:
# print statements regarding the model output


def models(df, feature_cols):
    '''This is a function that outputs the Intercept, Coefficients, 3 types of Errors, and R-Squared'''
    X = kc_train[feature_cols]
    y = kc_train['price']
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.5)
    linreg = LinearRegression()
    linreg.fit(X_train, y_train)
    print(f'Intercept of the regression line:',linreg.intercept_)
    print(f'Coefficients:',linreg.coef_)
    print('\n')
    
    y_pred = linreg.predict(X_test)

    
    print(f'Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
    print(f'Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
    print(f'Root Mean Squared Error:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
    print(f'R-Squared:',round(linreg.score(X,y),3))
    print('\n')
    
    print(f'Mean Absolute Error exp:', np.exp(metrics.mean_absolute_error(y_test, y_pred)))
    print(f'Mean Squared Error exp:', np.exp(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# ### MODEL 1
# Sqft vs Price

# %% [markdown]
# These are exploartory models, so that we can compare our cross validated data with baseline models.

# %%
models(df=kc_train, feature_cols=['sqft_living'])
# Out:
# Intercept of the regression line: 12.160349743970412
# Coefficients: [0.00039946]
#
#
# Mean Absolute Error: 0.2740528702078951
# Mean Squared Error: 0.11210782980596068
# Root Mean Squared Error: 0.3348250734427765
# R-Squared: 0.562
#
#
# Mean Absolute Error exp: 1.315284339756961
# Mean Squared Error exp: 1.1186334761726306

# %% [markdown]
# ### Model 2
# Sqft Living, Bedrooms, Bathrooms vs Price. All of these factors are attributes of the house, and may increase or decrease price depending on whether they increase or decrease.

# %%
models(df=kc_train, feature_cols=['sqft_living','bedrooms','bathrooms'])
# Out:
# Intercept of the regression line: 12.2375106558752
# Coefficients: [ 0.00038733 -0.07571278  0.08368282]
#
#
# Mean Absolute Error: 0.2690709962489773
# Mean Squared Error: 0.10626604102192722
# Root Mean Squared Error: 0.3259847251358984
# R-Squared: 0.579
#
#
# Mean Absolute Error exp: 1.3087480539508807
# Mean Squared Error exp: 1.1121177060844145

# %% [markdown]
# ### MODEL 3
# SqFt_Living15, Sqft_Lot15, Grade vs Price: These factors were selected to see if there was a correlation between quality of neighborhood vs the price of home.

# %%
models(df=kc_train, feature_cols=['sqft_living15','sqft_lot15','grade'])
# Out:
# Intercept of the regression line: 10.583546701746684
# Coefficients: [1.27352421e-04 4.44669785e-07 2.73036320e-01]
#
#
# Mean Absolute Error: 0.24979332983118066
# Mean Squared Error: 0.09996718419208857
# Root Mean Squared Error: 0.3161758754112789
# R-Squared: 0.62
#
#
# Mean Absolute Error exp: 1.2837600743582227
# Mean Squared Error exp: 1.105134651594151

# %% [markdown]
# ## Model Comparison Graph

# %%
Values ={'Model 1': 0.337, 'Model 2': 0.325, 
         'Model 3': 0.310, 'Model 4': 0.300,}

plt.bar(range(len(Values)), list(Values.values()), color = ('Black'))
plt.xlabel('Models')
plt.ylabel('RMSE')
plt.title('RMSE Scores')
plt.show()

# %% [markdown]
# ## Model 4

# %% [markdown]
# This is our first more in depth model, where we are testing using train, test splits and cross validation to evaluate.

# %%
kc_train.head()
# Out:
#          date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 4   2/18/2015  13.142166         3       2.00         1680      8080     1.0
# 5   5/12/2014  14.022525         4       4.50         5420    101930     1.0
# 6   6/27/2014  12.458775         3       2.25         1715      6819     2.0
# 9   3/12/2015  12.685408         3       2.50         1890      6560     2.0
# 13  10/7/2014  12.899220         3       1.75         1370      9680     1.0
#
#     waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 4          0.0   0.0          3      8        1680            0.0      1987
# 5          0.0   0.0          3     11        3890         1530.0      2001
# 6          0.0   0.0          3      7        1715            0.0      1995
# 9          0.0   0.0          3      7        1890            0.0      2003
# 13         0.0   0.0          4      7        1370            0.0      1977
#
#    zipcode  sqft_living15  sqft_lot15  log_sqft  log_bedrooms  log_yr_built
# 4    98074           1800        7503  7.426549      1.098612      7.594381
# 5    98053           4760      101930  8.597851      1.386294      7.601402
# 6    98003           2238        6819  7.447168      1.098612      7.598399
# 9    98038           2390        7570  7.544332      1.098612      7.602401
# 13   98074           1370       10208  7.222566      1.098612      7.589336

# %% [markdown]
# ## Cross Validation

# %%
feature_col = ['log_sqft', 'grade']
X = kc_train[feature_col]
y = kc_train['price']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.5)

linreg1 = LinearRegression()
results = linreg1.fit(X_train, y_train)

print(np.exp(linreg1.intercept_))
# Out:
# 1699.6779264662428

# %%
print (X_train.shape, y_train.shape)
# Out:
# (2009, 2) (2009,)

# %%
predictions = np.exp(linreg1.predict(X_test))
predictions[0:5]
# Out:
# array([570270.77717299, 709099.97032862, 335661.18813672, 781214.67094238,
#        648384.71072246])

# %%
standardY= np.exp((y_test))
standard = (predictions)

# %%
print('RMSE')
print(np.sqrt(sum((standardY - standard) ** 2) / len(standardY)))
# Out:
# RMSE
# 224481.47845153138

# %%
print('R^2')
print('Score', linreg1.score(X_test, y_test))
# Out:
# R^2
# Score 0.6535336053669751

# %%
scores = cross_val_score(linreg1, X, y, cv=5)
print('Cross Validated Scores', scores)
# Out:
# Cross Validated Scores [0.65023275 0.68626122 0.63325295 0.69337311 0.61934235]

# %%
plt.scatter(standardY, standard)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Predictions vs True Values')
# Out:
# Text(0.5, 1.0, 'Predictions vs True Values')

# %% [markdown]
# # Model 5 (Final Model)
#
# Model 4 was fairly accurate when considering R-Squared, however the RMSE was way too high. So we decided to take the 90th percentile of our data in order to remove outliers, in hopes that this would allow our model to more accurately predict housing prices.

# %% [markdown]
# We use the built in Numpy percentile function to create a slice of our original data frame with only the top 90% of prices to avoid outliers.

# %%
kc_90_df = np.percentile(kc_train['price'], 90)
kc_90 = kc_train.drop(kc_train[kc_train['price'] > kc_90_df].index)

# %% [markdown]
# This is where we ran our train test split with our new outlier free dataframe.

# %%
feature_col = ['log_sqft', 'grade', 'log_yr_built']
X1 = kc_90[feature_col]
y1 = kc_90['price']

X1_train, X1_test, y1_train, y1_test = train_test_split(X1,y1, test_size =0.5)

linreg2 = LinearRegression()
results = linreg2.fit(X1_train, y1_train)

print(np.exp(linreg2.intercept_))
# Out:
# 3.7058998380941392e-06

# %% [markdown]
# Using the Numpy Exp function to revert our data back into numeric data that can be more easily interpreted.

# %%
predictions1 = np.exp(linreg2.predict(X1_test))
predictions[0:5]
# Out:
# array([570270.77717299, 709099.97032862, 335661.18813672, 781214.67094238,
#        648384.71072246])

# %%
standardY1= np.exp((y1_test))
standard1 = (predictions1)
standard2 = y1_test

# %% [markdown]
# RMSE is our evaluation method, and this is a manual formula that calcutes the RMSE of our test.

# %%
print('RMSE')
print(np.sqrt(sum((standardY1 - standard1) ** 2) / len(standardY)))
# Out:
# RMSE
# 120204.82241063895

# %% [markdown]
# This model has returned a much higher RMSE, meaning that we have a more accruate model than before.

# %%
print('MAE')
print(np.log(metrics.mean_absolute_error(standard2, predictions1)))
# Out:
# MAE
# 13.024726689484497

# %%
print('Linreg2 Coef')
print(np.exp(linreg2.coef_))
# Out:
# Linreg2 Coef
# [1.51752669 1.19651465 4.66956556]

# %% [markdown]
# These are our coeffiecients of our model, these will help us describe the exact impact our features have on the houses price.

# %%
print('Score', linreg2.score(X1_test, y1_test))
# Out:
# Score 0.5319245098301777

# %%
scores = cross_val_score(linreg2, X1, y1, cv=7)
print('Cross Validated Scores', scores)
# Out:
# Cross Validated Scores [0.49560265 0.53699745 0.53286165 0.49332393 0.55800122 0.52005495
#  0.49860576]

# %%
fig, ax = plt.subplots()
for color in ['green', 'blue']:
    x = standardY1
    y = standard1
    scale = 200.0
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# Our last visual represents the true Y values vs our predicted values, which appears to have a pretty similar layout.
